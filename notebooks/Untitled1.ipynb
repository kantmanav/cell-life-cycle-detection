# %%
import os
import numpy as np

import tensorflow as tf
import tensorflow_addons as tfa
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
print(tf.__version__)
AUTOTUNE = tf.data.experimental.AUTOTUNE

import deepcell
from deepcell_tracking.utils import Track, load_trks
from sklearn.model_selection import train_test_split
from deepcell.utils.data_utils import reshape_movie
from deepcell.utils.transform_utils import erode_edges
from deepcell.data import split_dataset
from deepcell_toolbox.processing import normalize, histogram_normalization

import spektral
# Out:
# 2.5.0
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
TE = tf.keras.models.load_model('/data/models/ssl')
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# ...

# %%
import keras.losses
keras.losses.self_supervised_loss = custom_loss
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8ddefec497c4> in <module>
#       1 import keras.losses
# ----> 2 keras.losses.self_supervised_loss = custom_loss
#
# NameError: name 'custom_loss' is not defined

# %%
TE = tf.keras.models.load_model('/data/models/ssl', custom_objects={'self_supervised_loss': self_supervised_loss})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-da51494020d2> in <module>
# ----> 1 TE = tf.keras.models.load_model('/data/models/ssl', custom_objects={'self_supervised_loss': self_supervised_loss})
#
# NameError: name 'self_supervised_loss' is not defined

# %%
TE = tf.keras.models.load_model('/data/models/ssl', custom_objects={'appearances_decoder': self_supervised_loss})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a43e3526dd26> in <module>
# ----> 1 TE = tf.keras.models.load_model('/data/models/ssl', custom_objects={'appearances_decoder': self_supervised_loss})
#
# NameError: name 'self_supervised_loss' is not defined
